# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import koopomics as ko
import pandas as pd
import torch.nn as nn

# %%
embedding_model = ko.FF_AE([50,2000,30], [30,2000,50])
operator_model = ko.LinearizingKoop(linearizer=ko.FFLinearizer([30,2000,40], [40,2000,30]), koop=ko.InvKoop(latent_dim=40, reg='skewsym'))

TestingKoop = ko.KoopmanModel(embedding=embedding_model, operator=operator_model)
# Out:
# Skew-Symmetric Matrix initialized with 780 trainable parameters.
# Skew-Symmetric Matrix initialized with 780 trainable parameters.
# Model loaded with:
# FF_AE module
# LinearizingKoop module
# An invertible Koop

# %%
param_path = '/Users/daviddornig/Documents/Master_Thesis/Bioinf/Code/philipp-trinh/KOOPOMICS/examples/TestingKoop.pth'
TestingKoop.load_state_dict(torch.load(param_path))
# Out:
# <All keys matched successfully>

# %%
import numpy as np

def add_noise(df, noise_level=0.01, augment_percentage=0.3, sample_id, time_id, replicate_id):
    df_augmented = df.copy()
    
    # Determine the number of samples to augment
    n_samples = int(len(df) * augment_percentage)
    
    # Randomly select samples to apply noise
    samples_to_augment = df.sample(n=n_samples, random_state=42)

    # Add noise
    noise = np.random.normal(0, noise_level, samples_to_augment[feature_list].shape)
    samples_to_augment[feature_list] += noise

    # Combine the original and augmented samples
    df_augmented = pd.concat([df, samples_to_augment])

    df_augmented = df_augmented.sort_values(by=[sample_id, time_id, replicate_id])
    df_augmented = df_augmented.reset_index(drop=True)
    
    return df_augmented
# Augment the training dataset by adding noise

sample_identifier = '', time_identifier, replicate_identifier
train_set_df_augmented = add_noise(train_set_df, noise_level=0.01, sample_identifier, time_identifier, replicate_identifier)
train_augm_dataloader = ko.dataloader_AE(train_set_df_augmented, feature_list, sample_id=sample_id, time_id=time_id, batch_size=5)
train_set_df_augmented
# Out:
#        Cohort Labor onset  Birth GA/weeks Subject ID Condition  \
# 55  Discovery    advanced       39.857143       DP03   healthy
# 56  Discovery    advanced       39.857143       DP03   healthy
# 57  Discovery    advanced       39.857143       DP03   healthy
# 58  Discovery    advanced       39.857143       DP03   healthy
# 59  Discovery    advanced       39.857143       DP03   healthy
# 60  Discovery    advanced       39.857143       DP03   healthy
# 61  Discovery    advanced       39.857143       DP03   healthy
# 62  Discovery    advanced       39.857143       DP03   healthy
# 63  Discovery    advanced       39.857143       DP03   healthy
# 64  Discovery    advanced       39.857143       DP03   healthy
# 65  Discovery    advanced       39.857143       DP03   healthy
# 66  Discovery    advanced       39.857143       DP03   healthy
# 67  Discovery    advanced       39.857143       DP03   healthy
# 68  Discovery    advanced       39.857143       DP03   healthy
# ...

# %%
pregnancy_df = pd.read_csv('/Users/daviddornig/Documents/Master_Thesis/Bioinf/Code/philipp-trinh/KOOPOMICS/input_data/pregnancy/pregnancy_interpolated_featselected62M_robustscaled.csv')

sample_id = 'Subject ID'
time_id = 'Gestational age (GA)/weeks'
replicate_id = 'Condition'
feature_list = pregnancy_df.columns[7:]

train_set_df = pregnancy_df[pregnancy_df['Cohort'] == 'Discovery'].copy()
test_set_df = pregnancy_df[pregnancy_df['Cohort'] == 'Validation (Test Set 1)'].copy()
train_dataloader = ko.dataloader_AE(train_set_df, feature_list, sample_id=sample_id, time_id=time_id, batch_size=5)
test_dataloader = ko.dataloader_AE(test_set_df, feature_list, sample_id=sample_id, time_id=time_id, batch_size=5)

# %%
train_set_df
# Out:
#         Cohort Labor onset  Birth GA/weeks Subject ID Condition  \
# 0    Discovery     natural       38.714286       DP01   healthy
# 1    Discovery     natural       38.714286       DP01   healthy
# 2    Discovery     natural       38.714286       DP01   healthy
# 3    Discovery     natural       38.714286       DP01   healthy
# 4    Discovery     natural       38.714286       DP01   healthy
# ..         ...         ...             ...        ...       ...
# 465  Discovery     natural       38.571429       DP21   healthy
# 466  Discovery     natural       38.571429       DP21   healthy
# 467  Discovery     natural       38.571429       DP21   healthy
# 468  Discovery     natural       38.571429       DP21   healthy
# 469  Discovery     natural       38.571429       DP21   healthy
#
#      Gestational age (GA)/days  Gestational age (GA)/weeks  \
# 0                           35                           5
# 1                           42                           6
# ...

# %%
input_df = pregnancy_df.copy()
metabolite_names = input_df.columns[7:]
# df must have feature from column 6 onward and metadata until column 6.
#input_df[metabolite_names] =  input_df[metabolite_names].sub(average_row_mean, axis=0)

input_tensor = torch.tensor(input_df.iloc[:, 7:].values, dtype=torch.float32)
input_tensor[0]
# Out:
# tensor([-1.4424, -2.2023, -0.6105,  0.5704,  1.4733,  1.6917,  0.6347,  3.4789,
#          3.4759,  1.1653, -0.6691,  0.4019, -1.0045,  0.9781, -0.6744,  0.3813,
#          2.5527, -0.3893, -2.1971,  0.7286,  1.0932, -4.3114, -1.3493,  1.6866,
#          1.1539, -1.9949, -3.2171, -1.5585,  3.3270, -3.1401, -4.0659, -0.0598,
#         -2.1093, -2.5716, -1.2221, -7.8121,  0.6287, -0.1930,  2.8206, -0.5932,
#         -1.5778, -1.4347, -4.4832, -1.8511,  0.2475, -0.6552, -5.0469, -4.3929,
#          1.2227, -0.5278,  4.5114, -0.5930, -3.3687,  4.2844,  3.0976,  0.2213,
#          0.6778, -1.4817, -0.8550,  2.6132, -1.0299,  2.7675, -0.7996, -2.0322,
#          1.4367,  1.1702, -0.3100,  2.8633,  0.2742,  2.2207, -1.6458,  0.5513,
#          2.5245,  1.9290,  3.4519, -0.1615,  0.9453,  0.3212,  3.4990, -2.9123,
#         -2.2305, -2.5669, -0.0283, -2.3486,  1.6477, -2.0056, -1.2415,  1.2639,
#          3.4499, -0.7323,  2.7940,  0.9982,  5.6954, -2.1027,  0.7507, -0.9040,
# ...

# %%
pregnancy_df[feature_list[0]]
# Out:
# 0       5
# 1       6
# 2       7
# 3       8
# 4       9
#        ..
# 696    35
# 697    36
# 698    37
# 699    38
# 700    39
# Name: Gestational age (GA)/weeks, Length: 701, dtype: int64

# %%
model = ko.NaiveMeanPredictor()
model.fit(train_set_df, feature_list)
feature_errors = model.calculate_reference_values(train_augm_dataloader, test_dataloader, max_Kstep=2, featurewise=True, normalize=False)
feature_errors
# Out:
# ({'fwd_feature_errors': {0: 0.48277262150448685,
#    1: 0.4999748777518881,
#    2: 0.490367099504046,
#    3: 0.44831189830252466,
#    4: 0.074749819874922,
#    5: 1.0111269226416628,
#    6: 0.4204298453108269,
#    7: 0.4513110637669749,
#    8: 0.37160616830744325,
#    9: 0.5996450568311551,
#    10: 0.53263985711779,
#    11: 0.4237505727784431,
#    12: 0.39430698946593923,
#    13: 0.44595272583451046,
#    14: 0.47984566016400115,
#    15: 0.41504458207488454,
#    16: 0.3337691304313534,
#    17: 0.5102036798699818,
#    18: 0.46837142537882986,
#    19: 0.46902583052523117,
#    20: 0.4841871274377596,
#    21: 0.5232962423618487,
#    22: 0.6416262349886621,
#    23: 0.591834754217416,
#    24: 0.5949764523705953,
#    25: 0.553486972967995,
#    26: 0.7386191859940424,
#    27: 0.5735503566510817,
#    28: 0.4721407923015191,
#    29: 0.5828945811124558,
#    30: 0.4243235911262479,
#    31: 0.5585209870057062,
#    32: 1.1242850691357509,
# ...

# %%
print('Train Set Error Naive Model')

print(feature_errors[0]['total_fwd_loss'])
print(feature_errors[0]['total_bwd_loss'])

print('Test Set Error Naive Model')

print(feature_errors[1]['total_fwd_loss'])
print(feature_errors[1]['total_bwd_loss'])
# Out:
# Train Set Error Naive Model
# tensor(0.4991)
# tensor(0.5040)
# Test Set Error Naive Model
# tensor(0.5543)
# tensor(0.5834)

# %%
0.4/2.7191
# Out:
# 0.14710749880475157

# %%
loss_dict = ko.test(TestingKoop, test_dataloader, max_Kstep=10, disable_tempcons=True)

# %%
(np.mean([0.2414, 0.2521]) - np.mean([0.1690, 0.1705]))/np.mean([0.2414, 0.2521])
# Out:
# 0.31205673758865243

# %%
loss_dict
# Out:
# {'test_fwd_loss': tensor(0.1690),
#  'test_bwd_loss': tensor(0.1705),
#  'test_temp_cons_loss': 0,
#  'test_inv_cons_loss': 69.14029538631439,
#  'dict_fwd_step_loss': {1: 0.15234099074881127,
#   2: 0.16060375152750217,
#   3: 0.1611820911948985,
#   4: 0.1706573593806713,
#   5: 0.16564629837236505,
#   6: 0.17315809381134967,
#   7: 0.18049894602216304,
#   8: 0.18266494869393238,
#   9: 0.17074395422922803,
#   10: 0.17294085770845413},
#  'dict_fwd_step_tempcons_loss': {},
#  'dict_bwd_step_loss': {1: 0.16073104644075353,
#   2: 0.1687493956786521,
#   3: 0.17549376403714748,
#   4: 0.1814922130805381,
#   5: 0.17309366142813196,
#   6: 0.17261325060687166,
#   7: 0.16555630550422568,
#   8: 0.1720392124608476,
#   9: 0.16489465138379564,
#   10: 0.1704227944162298},
#  'dict_bwd_step_tempcons_loss': {}}

# %%
bwdmatrix, fwdmatrix = TestingKoop.kmatrix()
bwdM = bwdmatrix.detach()
fwdM = fwdmatrix.detach()
fwdinv = np.linalg.inv(fwdM)

# %%
B, F = bwdM, fwdM


K = F.shape[-1]
loss_inv_cons = 0
for k in range(1,K+1):
    Fs1 = F[:,:k]
    Bs1 = B[:k,:]
    Fs2 = F[:k,:]
    Bs2 = B[:,:k]

    Ik = torch.eye(k).float()#.to(device)

    loss_inv_cons += (torch.sum((torch.matmul(Bs1, Fs1) - Ik)**2) + \
                         torch.sum((torch.matmul(Fs2, Bs2) - Ik)**2) ) / (2.0*k)

loss_inv_cons
# Out:
# tensor(69.1403)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))  # 1 row, 2 columns

# First heatmap (for bwdM)
sns.heatmap(bwdM, annot=False, fmt=".2f", cmap='viridis', ax=ax1)
ax1.set_title('Backward Matrix Heatmap')
ax1.set_xlabel('Columns')
ax1.set_ylabel('Rows')

# Second heatmap (for fwdM)
sns.heatmap(fwdM, annot=False, fmt=".2f", cmap='viridis', ax=ax2)
ax2.set_title('Forward Matrix Heatmap')
ax2.set_xlabel('Columns')
ax2.set_ylabel('Rows')

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the subplots
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))  # 1 row, 2 columns

# First heatmap (for bwdM)
sns.heatmap(bwdM, annot=False, fmt=".2f", cmap='viridis', ax=ax1)
ax1.set_title('Backward Matrix Heatmap')
ax1.set_xlabel('Columns')
ax1.set_ylabel('Rows')

# Second heatmap (for fwdM)
sns.heatmap(fwdinv, annot=False, fmt=".2f", cmap='viridis', ax=ax2)
ax2.set_title('Inverted Forward Matrix Heatmap')
ax2.set_xlabel('Columns')
ax2.set_ylabel('Rows')

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the subplots
plt.show()

# %%
eigenvalues, eigenvectors = np.linalg.eig(fwdM)
print("FWD Matrix:")
print(fwdM)
print("\nEigenvalues:")
print(list(eigenvalues))
print("\nEigenvectors:")
print(list(eigenvectors))
# Out:
# FWD Matrix:
# tensor([[ 0.0000, -0.0152,  0.1482,  ...,  0.0990,  0.0425,  0.3007],
#         [ 0.0152,  0.0000,  0.2043,  ...,  0.2413,  0.2126,  0.0528],
#         [-0.1482, -0.2043,  0.0000,  ..., -0.0101,  0.2265,  0.1197],
#         ...,
#         [-0.0990, -0.2413,  0.0101,  ...,  0.0000,  0.3077,  0.2345],
#         [-0.0425, -0.2126, -0.2265,  ..., -0.3077,  0.0000,  0.0773],
#         [-0.3007, -0.0528, -0.1197,  ..., -0.2345, -0.0773,  0.0000]])
#
# Eigenvalues:
# ...

# %%
eigenvalues, eigenvectors = np.linalg.eig(bwdM)
print("BWD Matrix:")
print(bwdM)
print("\nEigenvalues:")
print(list(eigenvalues))
print("\nEigenvectors:")
print(list(eigenvectors))
# Out:
# BWD Matrix:
# tensor([[-0.1265, -0.1806, -0.0028,  ..., -0.0541,  0.0777,  0.1530],
#         [ 0.1207,  0.0446,  0.6074,  ..., -0.1888,  0.0765,  0.3192],
#         [ 0.2069, -0.2502,  0.0018,  ...,  0.0929, -0.1222, -0.4439],
#         ...,
#         [ 0.0933,  0.3598,  0.0100,  ...,  0.2621, -0.0545,  0.1080],
#         [ 0.0012,  0.1601,  0.1245,  ..., -0.2298,  0.1376,  0.0985],
#         [-0.0857, -0.1694,  0.0516,  ...,  0.4059,  0.3340,  0.2048]])
#
# Eigenvalues:
# ...
