# %%
import importlib
import pandas as pd
import numpy as np
import koopomics.training.data_loader as dl
import koopomics.model as ko
importlib.reload(dl)
# Out:
# <module 'koopomics.training.data_loader' from '/Users/daviddornig/Documents/Master_Thesis/Bioinf/Code/philipp-trinh/KOOPOMICS/koopomics/training/data_loader.py'>

# %%
import koopomics.training.train_utils as tr
importlib.reload(tr)
# Out:
# <module 'koopomics.training.train_utils' from '/Users/daviddornig/Documents/Master_Thesis/Bioinf/Code/philipp-trinh/KOOPOMICS/koopomics/training/train_utils.py'>

# %%
pregnancy_df = pd.read_csv('/Users/daviddornig/Documents/Master_Thesis/Bioinf/Code/philipp-trinh/KOOPOMICS/input_data/pregnancy/pregnancy_interpolated_featselected30M_robustscaled.csv')

sample_id = 'Subject ID'
time_id = 'Gestational age (GA)/weeks'
replicate_id = 'Condition'

feature_list = pregnancy_df.columns[7:]

train_set_df = pregnancy_df[pregnancy_df['Cohort'] == 'Discovery'].copy()
test_set_df = pregnancy_df[pregnancy_df['Cohort'] == 'Validation (Test Set 1)'].copy()

train_dataloader = dl.dataloader_AE(train_set_df, feature_list, sample_id=sample_id, time_id=time_id, batch_size=30)
test_dataloader = dl.dataloader_AE(test_set_df, feature_list, sample_id=sample_id, time_id=time_id, batch_size=30)

# %%
import numpy as np

def add_noise(df, sample_id, time_id, replicate_id, noise_level=0.01, augment_percentage=0.3):
    df_augmented = df.copy()
    
    # Determine the number of samples to augment
    n_samples = int(len(df) * augment_percentage)
    
    # Randomly select samples to apply noise
    samples_to_augment = df.sample(n=n_samples, random_state=42)

    # Add noise
    noise = np.random.normal(0, noise_level, samples_to_augment[feature_list].shape)
    samples_to_augment[feature_list] += noise

    # Combine the original and augmented samples
    df_augmented = pd.concat([df, samples_to_augment])

    df_augmented = df_augmented.sort_values(by=[sample_id, time_id, replicate_id])
    df_augmented = df_augmented.reset_index(drop=True)
    
    return df_augmented
# Augment the training dataset by adding noise

train_set_df_augmented = add_noise(train_set_df, sample_id, time_id, replicate_id, noise_level=0.01)
train_augm_dataloader = dl.dataloader_AE(train_set_df_augmented, feature_list, sample_id=sample_id, time_id=time_id, batch_size=30)
train_set_df_augmented
# Out:
#         Cohort Labor onset  Birth GA/weeks Subject ID Condition  \
# 0    Discovery     natural       38.714286       DP01   healthy
# 1    Discovery     natural       38.714286       DP01   healthy
# 2    Discovery     natural       38.714286       DP01   healthy
# 3    Discovery     natural       38.714286       DP01   healthy
# 4    Discovery     natural       38.714286       DP01   healthy
# ..         ...         ...             ...        ...       ...
# 606  Discovery     natural       38.571429       DP21   healthy
# 607  Discovery     natural       38.571429       DP21   healthy
# 608  Discovery     natural       38.571429       DP21   healthy
# 609  Discovery     natural       38.571429       DP21   healthy
# 610  Discovery     natural       38.571429       DP21   healthy
#
#      Gestational age (GA)/days  Gestational age (GA)/weeks  \
# 0                           35                           5
# 1                           35                           5
# ...

# %%
len(feature_list)
# Out:
# 30

# %%
embedding_model = ko.FF_AE([len(feature_list),2000,3], [3,2000,len(feature_list)],E_dropout_rates= [0.5,0,0])
operator_model = ko.LinearizingKoop(linearizer=ko.FFLinearizer([3,1000,10], [10,1000,3], linE_dropout_rates=[0,0,0]), koop=ko.InvKoop(latent_dim=10, reg='skewsym'))

TestingKoop = ko.KoopmanModel(embedding=embedding_model, operator=operator_model)
# Out:
# 50.0 % dropout for input layer initialized.
# 50.0 % dropout for input layer initialized.
# Skew-Symmetric Matrix initialized with 45 trainable parameters.
# Skew-Symmetric Matrix initialized with 45 trainable parameters.
# Model loaded with:
# FF_AE module
# LinearizingKoop module
# An invertible Koop

# %%
tr.train_embedding(TestingKoop, train_augm_dataloader, test_dataloader, 
                   lr= 0.001, learning_rate_change=0.80, 
                   num_epochs=30, decayEpochs=[3, 6, 9, 12, 15, 18, 21, 24, 27],
                   weight_decay=0.1, gradclip=5, model_name='TestingKoop143M')
# Out:
# Training interrupted. Saving model...

# %%
import torch

param_path = '/Users/daviddornig/Documents/Master_Thesis/Bioinf/Code/philipp-trinh/KOOPOMICS/examples/TestingKoop143M_embedding_trained.pth'
TestingKoop.embedding.load_state_dict(torch.load(param_path))
# Out:
# <All keys matched successfully>

# %%
for param in TestingKoop.embedding.parameters():
        param.requires_grad = False

for name, param in TestingKoop.named_parameters():
    print(f"Parameter: {name}, Frozen: {not param.requires_grad}")
# Out:
# Parameter: embedding.encode.1.weight, Frozen: True
# Parameter: embedding.encode.1.bias, Frozen: True
# Parameter: embedding.encode.3.weight, Frozen: True
# Parameter: embedding.encode.3.bias, Frozen: True
# Parameter: embedding.decode.0.weight, Frozen: True
# Parameter: embedding.decode.0.bias, Frozen: True
# Parameter: embedding.decode.2.weight, Frozen: True
# Parameter: embedding.decode.2.bias, Frozen: True
# Parameter: operator.linearizer.lin_encode.1.weight, Frozen: False
# Parameter: operator.linearizer.lin_encode.1.bias, Frozen: False
# Parameter: operator.linearizer.lin_encode.3.weight, Frozen: False
# Parameter: operator.linearizer.lin_encode.3.bias, Frozen: False
# Parameter: operator.linearizer.lin_decode.0.weight, Frozen: False
# Parameter: operator.linearizer.lin_decode.0.bias, Frozen: False
# Parameter: operator.linearizer.lin_decode.2.weight, Frozen: False
# Parameter: operator.linearizer.lin_decode.2.bias, Frozen: False
# ...

# %%
importlib.reload(tr)

# Run training loop
tr.train(TestingKoop, train_augm_dataloader, test_dataloader, 
         lr= 0.001, learning_rate_change=0.8, loss_weights=[1,1,0.01,1], 
         num_epochs=30, decayEpochs=[3, 6, 9, 12, 15, 18, 21, 24, 27],
         weight_decay=0.001, gradclip=1, max_Kstep=2,
         print_batch_info=True, model_name='TestingKoop62M')
# Out:
# ----------Training epoch--------
# ----------------11---------------
#
# ---------------Batch Nr. 1353-------------------
# Total Loss: 0.6817935705184937
# FwdLoss: 0.3501191735267639
# BwdLoss: 0.3166041970252991
# Inv_Cons_Loss: 1.4982659816741943
# Temp_Cons_Loss: 8.758666081121191e-05
# ---------------Batch Nr. 1354-------------------
# Total Loss: 0.5627282857894897
# FwdLoss: 0.31368041038513184
# BwdLoss: 0.2339809238910675
# Inv_Cons_Loss: 1.49799644947052
# Temp_Cons_Loss: 8.702755440026522e-05
# ---------------Batch Nr. 1355-------------------
# Total Loss: 0.6031542420387268
# FwdLoss: 0.26728710532188416
# BwdLoss: 0.3208203911781311
# Inv_Cons_Loss: 1.4976425170898438
# Temp_Cons_Loss: 7.033624569885433e-05
# ---------------Batch Nr. 1356-------------------
# Total Loss: 0.5752575397491455
# FwdLoss: 0.2343129813671112
# BwdLoss: 0.3258678913116455
# Inv_Cons_Loss: 1.4973366260528564
# Temp_Cons_Loss: 0.00010328162898076698
# ...

# %%
for name, param in TestingKoop.named_parameters():
    print(f"Parameter: {name}, Frozen: {not param.requires_grad}")
# Out:
# Parameter: embedding.encode.1.weight, Frozen: True
# Parameter: embedding.encode.1.bias, Frozen: True
# Parameter: embedding.encode.3.weight, Frozen: True
# Parameter: embedding.encode.3.bias, Frozen: True
# Parameter: embedding.decode.0.weight, Frozen: True
# Parameter: embedding.decode.0.bias, Frozen: True
# Parameter: embedding.decode.2.weight, Frozen: True
# Parameter: embedding.decode.2.bias, Frozen: True
# Parameter: operator.linearizer.lin_encode.1.weight, Frozen: False
# Parameter: operator.linearizer.lin_encode.1.bias, Frozen: False
# Parameter: operator.linearizer.lin_encode.4.weight, Frozen: False
# Parameter: operator.linearizer.lin_encode.4.bias, Frozen: False
# Parameter: operator.linearizer.lin_decode.0.weight, Frozen: False
# Parameter: operator.linearizer.lin_decode.0.bias, Frozen: False
# Parameter: operator.linearizer.lin_decode.2.weight, Frozen: False
# Parameter: operator.linearizer.lin_decode.2.bias, Frozen: False
# ...
