# %% [markdown]
# # Pregnancy data Preprocessing

# %%
import pandas as pd
import matplotlib.pyplot as plt
import ipywidgets as widgets
import seaborn as sns
import numpy as np
from IPython.display import display

# %%
df = pd.read_csv('/Users/daviddornig/Documents/Master_Thesis/Bioinf/Code/philipp-trinh/KOOPOMICS/input_data/pregnancy/pregnancy_mmc2.csv')

# %%
df
# Out:
#     Subject ID Gestational age (GA)/weeks Birth GA/weeks  \
# 0         DP30                20,85714286    38,85714286
# 1         DP25                17,85714286    40,28571429
# 2         DP28                25,42857143    41,71428571
# 3         DP30                14,71428571    38,85714286
# 4         DP24                6,142857143    41,71428571
# ..         ...                        ...            ...
# 776       DP14                18,28571429    38,57142857
# 777       DP14                37,42857143    38,57142857
# 778       DP14                35,71428571    38,57142857
# 779       DP14                16,71428571    38,57142857
# 780       DP13                16,85714286    37,71428571
#
#                       Cohort Labor onset (+)-.alpha.-Tocopherol  \
# 0    Validation (Test Set 1)     natural            12,54588523
# 1    Validation (Test Set 1)     natural            12,21083399
# 2    Validation (Test Set 1)     natural            12,83140703
# 3    Validation (Test Set 1)     natural            12,50117026
# 4    Validation (Test Set 1)    advanced            11,94764115
# ..                       ...         ...                    ...
# 776                Discovery    advanced            13,08891799
# 777                Discovery    advanced            13,55370186
# 778                Discovery    advanced            12,86045746
# 779                Discovery    advanced            12,32921604
# 780                Discovery     natural             11,3691136
#
#     (R)-2-Hydroxycaprylic acid 1,4-Dihydroxybenzene 1-Methylxanthine  \
# 0                   10,4705179          9,378165083      10,33662253
# 1                  10,78090374          8,881251127      11,89150494
# 2                  9,937180674          9,404730038      11,29504421
# 3                  10,53108337          9,397824811      9,422072249
# 4                  10,98394827          7,487139835       2,90878903
# ..                         ...                  ...              ...
# 776                10,02485393          9,419754632      11,17242641
# 777                10,27230487          9,460037221      10,61519508
# 778                10,51835577          9,474270908      11,63192294
# 779                10,54310981          9,371263666      9,860474816
# 780                10,51204458          9,479575693      11,14194999
#
#     1-Naphthylamine  ... cis-5,8,11,14,17-Eicosapentaenoic acid  \
# 0       12,52174292  ...                            10,81158182
# 1       12,64456521  ...                            9,555634626
# 2       12,80809496  ...                            11,56274443
# 3       12,44195011  ...                            10,76770044
# 4       12,88779131  ...                            11,41754784
# ..              ...  ...                                    ...
# 776     12,45323145  ...                            11,18874105
# 777     12,25303865  ...                            10,92123449
# 778     12,23617267  ...                            10,92041876
# 779     12,74696352  ...                            11,16102778
# 780     12,54296156  ...                            10,87277934
#
#     cis-5-Dodecenoic acid cis-9-Palmitoleic acid   d-LIMONENE   gamma-CEHC  \
# 0             9,970392291            12,22342841  8,020989125  9,419702688
# 1             9,462147473            12,00893347  7,996321409  10,20117735
# 2             8,916087158            12,02616732  7,714632099  9,087478678
# 3             9,315615038            12,33969313  7,887811609  10,43807228
# 4             8,795294016            11,60247012  6,683187084  10,04545316
# ..                    ...                    ...          ...          ...
# 776           8,920435788            11,99504092  6,549301709  9,901533267
# 777           9,514091297            12,14576413  7,257468438  9,375458599
# 778           9,191140552            12,23815699  6,865692682  9,815789879
# 779           9,035905738            12,06412635  7,934257221  8,591284938
# 780           7,398228277            11,92892471  7,233045128   10,8492501
#
#     gamma-Glutamylleucine ketoisocaproic acid     p-Cresol  \
# 0              12,3950719         15,12310272  10,87728909
# 1             12,39246515         14,72417037  11,17190085
# 2             12,58367961         15,09624416  11,10877339
# 3             12,34361059         15,15444351   10,9262012
# 4             12,63004438         15,35433399  11,19040965
# ..                    ...                 ...          ...
# 776            12,4574568         14,83772335  10,84213542
# 777           12,17843565         13,86323096  10,88890009
# 778           12,32771357         14,15521459  11,32259447
# 779           12,46616051         14,87474764    10,008749
# 780           12,14648935         14,85349795   11,4150337
#
#     phenylacetylglutamine trans-Vaccenic acid
# 0             14,83427949         11,39565369
# 1             15,62233247         11,29511195
# 2             14,93028219         11,01955193
# 3             14,88573215         11,28907038
# 4             15,27611088         11,21358152
# ..                    ...                 ...
# 776           15,00174228         10,98308372
# 777           14,86956814         11,07428581
# 778            15,3712792         11,27298081
# 779           14,44060303         10,95715815
# 780           15,14862354         10,93344618
#
# [781 rows x 269 columns]

# %% [markdown]
# # Convert numerical columns to float

# %%
for col in df.columns:
    if df[col].dtype == 'object':  # Check if column is of object (string) type
        try:
            df[col] = df[col].str.replace(',', '.').astype(float)
        except:
            pass  # Skip columns that cannot be converted to float

# %% [markdown]
# # Normalize and impute for equal time intervals

# %%
# Calculate 'Gestational age (GA)/days' for easier Imputation Inspection:
df['Gestational age (GA)/days'] = df['Gestational age (GA)/weeks'] * 7

# Insert 'Gestational age (GA)/days' at position 1
df.insert(1, 'Gestational age (GA)/days', df.pop('Gestational age (GA)/days'))

metabolite_names = df.columns[6:]

agg_dict = {col: 'first' for col in df.columns if col not in metabolite_names}
agg_dict.update({col: 'mean' for col in metabolite_names})
df = df.groupby(['Subject ID', 'Gestational age (GA)/days'], as_index=False).agg(agg_dict)


df
# Out:
# /var/folders/jr/ft1vf12558n66z4wt6d17jpw0000gn/T/ipykernel_3574/3879062531.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['Gestational age (GA)/days'] = df['Gestational age (GA)/weeks'] * 7
# /var/folders/jr/ft1vf12558n66z4wt6d17jpw0000gn/T/ipykernel_3574/3879062531.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.insert(1, 'Gestational age (GA)/days', df.pop('Gestational age (GA)/days'))
#     Subject ID  Gestational age (GA)/days  Gestational age (GA)/weeks  \
# 0         DP01                       32.0                    4.571429
# 1         DP01                       38.0                    5.428571
# 2         DP01                       48.0                    6.857143
# 3         DP01                       53.0                    7.571429
# 4         DP01                       60.0                    8.571429
# ..         ...                        ...                         ...
# 776       DP30                      250.0                   35.714286
# 777       DP30                      258.0                   36.857143
# 778       DP30                      265.0                   37.857143
# 779       DP30                      271.0                   38.714286
# 780       DP30                      279.0                   39.857143
#
#      Birth GA/weeks                   Cohort Labor onset  \
# 0         38.714286                Discovery     natural
# 1         38.714286                Discovery     natural
# 2         38.714286                Discovery     natural
# 3         38.714286                Discovery     natural
# 4         38.714286                Discovery     natural
# ..              ...                      ...         ...
# 776       38.857143  Validation (Test Set 1)     natural
# 777       38.857143  Validation (Test Set 1)     natural
# 778       38.857143  Validation (Test Set 1)     natural
# 779       38.857143  Validation (Test Set 1)     natural
# 780       38.857143  Validation (Test Set 1)     natural
#
#      (+)-.alpha.-Tocopherol  (R)-2-Hydroxycaprylic acid  1,4-Dihydroxybenzene  \
# 0                 12.732931                   10.324349              9.427656
# 1                 11.641561                    9.826447              9.203357
# 2                 14.147322                    9.938783              5.004808
# 3                 11.575129                   10.373672              2.136988
# 4                 12.860203                   10.093378              9.402468
# ..                      ...                         ...                   ...
# 776               11.862181                   11.947307              6.934630
# 777               14.289563                   10.330582              6.810455
# 778               12.454016                   10.071125              9.166271
# 779               13.179933                   10.057040              9.374150
# 780               14.273780                   10.285989              6.853313
#
#      1-Methylxanthine  ...  cis-5,8,11,14,17-Eicosapentaenoic acid  \
# 0           10.062627  ...                               11.038446
# 1           11.751959  ...                               11.328136
# 2            9.759423  ...                               10.553957
# 3            9.542057  ...                               10.470219
# 4           10.156535  ...                               10.941490
# ..                ...  ...                                     ...
# 776         10.436540  ...                               11.129505
# 777         10.057725  ...                               10.804448
# 778          9.951338  ...                               10.462633
# 779          7.578201  ...                                9.444029
# 780         10.243169  ...                               11.468744
#
#      cis-5-Dodecenoic acid  cis-9-Palmitoleic acid  d-LIMONENE  gamma-CEHC  \
# 0                10.868139               12.060683    6.535749   10.743147
# 1                10.730683               12.058283    4.750516   10.248802
# 2                 9.479333               11.523967    6.618331    9.246354
# 3                 8.715487               11.987677    7.210929    9.728055
# 4                 8.890921               11.722946    7.175603   10.414715
# ..                     ...                     ...         ...         ...
# 776               9.544339               12.159645    6.922197    8.843032
# 777               9.117634               12.006049    6.130973   10.011394
# 778               9.734463               12.503588    6.481496    8.856269
# 779               9.480449               12.061958    8.330380    9.279075
# 780              10.140392               12.051686    6.532406   10.150753
#
#      gamma-Glutamylleucine  ketoisocaproic acid   p-Cresol  \
# 0                12.159468            14.494009  10.795374
# 1                12.156257            14.261366  10.474932
# 2                12.040974            14.152451  10.814819
# 3                12.707441            14.515774  10.980807
# 4                12.467874            15.060526  10.025831
# ..                     ...                  ...        ...
# 776              11.806709            14.398780  10.995573
# 777              12.119367            14.692128  10.483775
# 778              12.146217            14.608604  10.177440
# 779              12.639098            14.937081  10.366342
# 780              12.524897            14.461626  11.382722
#
#      phenylacetylglutamine  trans-Vaccenic acid
# 0                14.598038            11.161321
# 1                13.928455            11.138764
# 2                14.112078            10.603562
# 3                14.444065            11.112128
# 4                13.506372            11.213513
# ..                     ...                  ...
# 776              14.760980            10.953581
# 777              14.417119            10.759640
# 778              13.913940            11.100922
# 779              14.421513            11.325719
# 780              15.052686            11.292340
#
# [781 rows x 270 columns]

# %%
df_grouped = df.sort_values(['Subject ID', 'Gestational age (GA)/days']).groupby('Subject ID')
df_subject = df_grouped.get_group('DP01')  # Replace 'your_subject_id' with the actual ID
df_subject
# Out:
#    Subject ID  Gestational age (GA)/days  Gestational age (GA)/weeks  \
# 0        DP01                       32.0                    4.571429
# 1        DP01                       38.0                    5.428571
# 2        DP01                       48.0                    6.857143
# 3        DP01                       53.0                    7.571429
# 4        DP01                       60.0                    8.571429
# 5        DP01                       66.0                    9.428571
# 6        DP01                       82.0                   11.714286
# 7        DP01                       87.0                   12.428571
# 8        DP01                       94.0                   13.428571
# 9        DP01                      101.0                   14.428571
# 10       DP01                      108.0                   15.428571
# 11       DP01                      115.0                   16.428571
# 12       DP01                      123.0                   17.571429
# 13       DP01                      128.0                   18.285714
# 14       DP01                      139.0                   19.857143
# 15       DP01                      153.0                   21.857143
# 16       DP01                      159.0                   22.714286
# 17       DP01                      166.0                   23.714286
# 18       DP01                      171.0                   24.428571
# 19       DP01                      180.0                   25.714286
# 20       DP01                      186.0                   26.571429
# 21       DP01                      193.0                   27.571429
# 22       DP01                      199.0                   28.428571
# 23       DP01                      206.0                   29.428571
# 24       DP01                      212.0                   30.285714
# 25       DP01                      220.0                   31.428571
# 26       DP01                      227.0                   32.428571
# 27       DP01                      233.0                   33.285714
# 28       DP01                      241.0                   34.428571
# 29       DP01                      248.0                   35.428571
# 30       DP01                      255.0                   36.428571
# 31       DP01                      261.0                   37.285714
# 32       DP01                      270.0                   38.571429
# 33       DP01                      292.0                   41.714286
#
#     Birth GA/weeks     Cohort Labor onset  (+)-.alpha.-Tocopherol  \
# 0        38.714286  Discovery     natural               12.732931
# 1        38.714286  Discovery     natural               11.641561
# 2        38.714286  Discovery     natural               14.147322
# 3        38.714286  Discovery     natural               11.575129
# 4        38.714286  Discovery     natural               12.860203
# 5        38.714286  Discovery     natural               12.455080
# 6        38.714286  Discovery     natural               11.042513
# 7        38.714286  Discovery     natural               11.199496
# 8        38.714286  Discovery     natural               12.489910
# 9        38.714286  Discovery     natural               12.081367
# 10       38.714286  Discovery     natural               11.619046
# 11       38.714286  Discovery     natural               11.265065
# 12       38.714286  Discovery     natural               12.840329
# 13       38.714286  Discovery     natural               11.478407
# 14       38.714286  Discovery     natural               12.399822
# 15       38.714286  Discovery     natural               13.495054
# 16       38.714286  Discovery     natural               12.527253
# 17       38.714286  Discovery     natural               14.214328
# 18       38.714286  Discovery     natural               13.698102
# 19       38.714286  Discovery     natural               13.595196
# 20       38.714286  Discovery     natural               12.842124
# 21       38.714286  Discovery     natural               10.765269
# 22       38.714286  Discovery     natural               12.978320
# 23       38.714286  Discovery     natural               13.788580
# 24       38.714286  Discovery     natural               13.812438
# 25       38.714286  Discovery     natural               12.924677
# 26       38.714286  Discovery     natural               13.188629
# 27       38.714286  Discovery     natural               12.362176
# 28       38.714286  Discovery     natural               12.514409
# 29       38.714286  Discovery     natural               12.390296
# 30       38.714286  Discovery     natural               13.486200
# 31       38.714286  Discovery     natural               14.196021
# 32       38.714286  Discovery     natural               13.339476
# 33       38.714286  Discovery     natural               12.834852
#
#     (R)-2-Hydroxycaprylic acid  1,4-Dihydroxybenzene  1-Methylxanthine  ...  \
# 0                    10.324349              9.427656         10.062627  ...
# 1                     9.826447              9.203357         11.751959  ...
# 2                     9.938783              5.004808          9.759423  ...
# 3                    10.373672              2.136988          9.542057  ...
# 4                    10.093378              9.402468         10.156535  ...
# 5                    10.231863              6.857599         10.542357  ...
# 6                    11.389924              2.508999         11.001225  ...
# 7                     9.617054              9.279234         11.147373  ...
# 8                    10.344228              9.271445         10.120465  ...
# 9                     9.935351              9.398458         10.080994  ...
# 10                   10.266971              9.260679         10.961893  ...
# 11                   10.324611              9.274810         11.386055  ...
# 12                   10.652074              9.271941         10.894895  ...
# 13                   10.527077              5.499710         10.216753  ...
# 14                   10.299808              9.286847         10.103659  ...
# 15                   10.112993              9.357694          9.985024  ...
# 16                   10.050548              9.319380         10.008869  ...
# 17                    9.640449              9.323353         10.656773  ...
# 18                   10.183608              9.306749         11.682031  ...
# 19                    9.760295              9.268768         10.042595  ...
# 20                   10.271627              9.277177         10.819680  ...
# 21                   10.321979              6.283178         11.084119  ...
# 22                   10.453126              9.318489         11.405914  ...
# 23                   10.105246              9.365103         11.240190  ...
# 24                    9.896786              9.326969         10.694690  ...
# 25                   10.533475              9.231753         10.920399  ...
# 26                   10.237536              9.196147         10.599258  ...
# 27                   10.100346              9.221389         10.863014  ...
# 28                   10.106297              9.423097         10.853737  ...
# 29                   10.711420              9.284043         11.630221  ...
# 30                   10.422250              9.354928         10.956283  ...
# 31                   10.235143              4.627317         10.669664  ...
# 32                   10.162172              9.297399         11.221612  ...
# 33                   10.381262              9.040077         10.223318  ...
#
#     cis-5,8,11,14,17-Eicosapentaenoic acid  cis-5-Dodecenoic acid  \
# 0                                11.038446              10.868139
# 1                                11.328136              10.730683
# 2                                10.553957               9.479333
# 3                                10.470219               8.715487
# 4                                10.941490               8.890921
# 5                                10.635612               9.054934
# 6                                10.409214               9.634355
# 7                                11.149842               7.647583
# 8                                11.122967               8.819090
# 9                                10.659390               8.664196
# 10                               11.022082               8.489853
# 11                               10.461259               9.021319
# 12                               10.988374               8.563390
# 13                                9.422362               8.265268
# 14                               11.052410              10.422394
# 15                               11.000737               9.270129
# 16                               10.795390               9.139284
# 17                               11.156737              10.266570
# 18                               10.680712               9.179709
# 19                               11.465126              10.251565
# 20                               10.916060              10.231792
# 21                               11.047753               9.615492
# 22                               10.879124               9.301566
# 23                               10.467267               9.066285
# 24                               10.972771              10.313661
# 25                               10.591817               9.365281
# 26                               10.280650               9.881834
# 27                               10.682459               9.853856
# 28                               11.128050               9.896706
# 29                               10.800360               9.195509
# 30                               10.884261               9.820026
# 31                               11.157703              10.071905
# 32                               10.331900               9.361200
# 33                               10.108885               9.045214
#
#     cis-9-Palmitoleic acid  d-LIMONENE  gamma-CEHC  gamma-Glutamylleucine  \
# 0                12.060683    6.535749   10.743147              12.159468
# 1                12.058283    4.750516   10.248802              12.156257
# 2                11.523967    6.618331    9.246354              12.040974
# 3                11.987677    7.210929    9.728055              12.707441
# 4                11.722946    7.175603   10.414715              12.467874
# 5                11.940352    5.983672    9.649356              12.190841
# 6                12.098127    5.559825    9.852833              12.709039
# 7                12.093711    5.415494    9.684333              12.515518
# 8                12.005742    6.308748    9.717238              12.152344
# 9                11.944588    5.197372   10.559812              12.359319
# 10               11.888464    5.686531    9.605986              12.893222
# 11               12.092877    5.032591   10.353553              12.542136
# 12               11.986576    6.570598    9.849408              12.021149
# 13               12.036839    5.694331   10.393705              12.511512
# 14               12.143239    5.775899    9.534065              12.153045
# 15               11.931217    5.340770    9.874670              12.194199
# 16               12.019741    6.477072    9.479275              12.531847
# 17               12.125322    6.955170    9.527529              12.432335
# 18               11.827140    6.664836    9.412597              12.079799
# 19               12.368036    6.682358    8.807128              12.269697
# 20               12.059598    6.778514    9.623390              12.290652
# 21               12.199275    6.725763    9.711993              12.226804
# 22               11.976946    6.942808    9.829681              11.947690
# 23               11.704900    7.230407   10.028610              11.793888
# 24               12.003626    6.552380    9.433000              12.210797
# 25               12.035650    6.028606    9.695325              11.965126
# 26               12.092966    6.165796    9.068764              12.398650
# 27               11.987041    5.935853    9.282372              12.249708
# 28               12.216820    6.775211    9.490449              12.476864
# 29               11.954205    6.585743    9.964322              12.156302
# 30               11.819111    6.329011    9.456299              11.831714
# 31               11.802722    6.790321   10.016850              12.439996
# 32               11.841938    6.640462    9.586128              12.076009
# 33               11.727673    6.226541    9.937132              12.374136
#
#     ketoisocaproic acid   p-Cresol  phenylacetylglutamine  trans-Vaccenic acid
# 0             14.494009  10.795374              14.598038            11.161321
# 1             14.261366  10.474932              13.928455            11.138764
# 2             14.152451  10.814819              14.112078            10.603562
# 3             14.515774  10.980807              14.444065            11.112128
# 4             15.060526  10.025831              13.506372            11.213513
# 5             14.817743  10.582098              14.246153            10.957951
# 6             14.817743  11.173898              14.584749            11.094721
# 7             14.843679  10.689486              14.152736            11.147429
# 8             15.069766  11.170132              14.984251            11.114114
# 9             15.226084  10.790238              14.884649            11.028773
# 10            15.558628  10.728001              14.701614            11.024280
# 11            14.989724  11.065913              14.665663            11.181178
# 12            14.589417  10.824057              14.664008            10.982209
# 13            14.643184  11.092742              15.268430            11.071245
# 14            15.245307  10.537073              14.472753            11.365815
# 15            15.153230  10.568383              14.824293            10.991525
# 16            15.578186  11.079427              14.959122            11.013295
# 17            15.259897  10.542866              14.560249            11.244172
# 18            14.749133  11.038740              14.656294            10.850144
# 19            15.453414  10.883278              15.229872            11.402563
# 20            14.946155  11.226453              14.880184            11.014833
# 21            14.467268  11.579988              14.661852            11.187779
# 22            14.580644  10.509766              14.182725            11.103799
# 23            14.897648  10.926201              14.561367            10.752656
# 24            14.828753  10.960071              14.347025            11.157944
# 25            14.821152  10.808838              14.695181            10.954409
# 26            15.658438  11.008574              14.471174            11.096971
# 27            14.864059  10.971703              14.670769            11.011356
# 28            15.422306  11.087639              14.465131            11.335926
# 29            14.708487  11.428833              14.906245            10.913389
# 30            14.594227  11.124132              14.566052            10.761819
# 31            15.245852  10.863501              14.708273            11.015931
# 32            14.344563  11.046314              14.336998            10.893804
# 33            14.868134  12.059624              15.539563            10.747399
#
# [34 rows x 270 columns]

# %%
subject_info = []
for subject_id, _ in df_grouped:
    df_subject = df_grouped.get_group(subject_id)
    min_days = (df_subject['Gestational age (GA)/weeks'] * 7).diff().min()
    max_days = (df_subject['Gestational age (GA)/weeks'] * 7).diff().max()
    start_date = (df_subject['Gestational age (GA)/weeks'] * 7).min()
    end_date = (df_subject['Gestational age (GA)/weeks'] * 7).max()
    subject_info.append({'Subject ID': subject_id,
                        'Length': len(df_subject['Gestational age (GA)/weeks']),
                        'Min Days': min_days,
                        'Max Days': max_days,
                         'Start Date': start_date,
                         'End Date': end_date})

df_info = pd.DataFrame(subject_info)
df_info
# Out:
#    Subject ID  Length  Min Days  Max Days  Start Date  End Date
# 0        DP01      34       5.0      22.0        32.0     292.0
# 1        DP02      28       4.0      21.0        72.0     301.0
# 2        DP03      31       3.0      16.0        51.0     289.0
# 3        DP04      32       4.0      31.0        71.0     323.0
# 4        DP05      32       3.0      23.0        58.0     303.0
# 5        DP06      19       5.0       8.0       155.0     281.0
# 6        DP07      17       5.0      29.0       181.0     319.0
# 7        DP08      33       4.0      21.0        43.0     304.0
# 8        DP09      19       5.0      38.0        41.0     285.0
# 9        DP10      27       4.0      25.0        93.0     303.0
# 10       DP11      27       3.0      37.0        63.0     322.0
# 11       DP12      24       4.0      36.0        91.0     294.0
# 12       DP13      24       3.0      30.0       101.0     288.0
# 13       DP14      29       4.0      13.0        53.0     262.0
# 14       DP15      25       5.0      17.0       118.0     299.0
# 15       DP16      20       4.0      26.0       138.0     299.0
# 16       DP17      28       4.0      20.0        74.0     298.0
# 17       DP18      24       4.0      30.0       129.0     310.0
# 18       DP19      25       5.0      21.0        92.0     297.0
# 19       DP20      13       3.0      57.0       126.0     300.0
# 20       DP21      16       5.0      37.0       121.0     290.0
# 21       DP22      26       4.0      22.0       101.0     295.0
# 22       DP23      25       5.0      35.0        88.0     298.0
# 23       DP24      37       5.0      20.0        43.0     307.0
# 24       DP25      32       5.0      18.0        50.0     299.0
# 25       DP26      25       3.0      23.0        93.0     302.0
# 26       DP27      27       4.0      26.0        54.0     290.0
# 27       DP28      26       4.0      22.0       103.0     306.0
# 28       DP29      26       4.0      29.0        93.0     302.0
# 29       DP30      30       4.0      11.0        76.0     279.0

# %%
# Calculate the common start and end dates
common_start_date = df_info['Start Date'].min()
common_end_date = df_info['End Date'].max()

# Create a common timeline in days
common_timeline = np.arange(0, common_end_date+7, 7).astype(int)

# %%
common_timeline
# Out:
# array([  0,   7,  14,  21,  28,  35,  42,  49,  56,  63,  70,  77,  84,
#         91,  98, 105, 112, 119, 126, 133, 140, 147, 154, 161, 168, 175,
#        182, 189, 196, 203, 210, 217, 224, 231, 238, 245, 252, 259, 266,
#        273, 280, 287, 294, 301, 308, 315, 322, 329])

# %%
# Find the index of the closest value greater than or equal to the start date
start_index = np.searchsorted(common_timeline, common_start_date, side='right')
if start_index > 0 and (abs(common_timeline[start_index] - common_start_date)) > (abs(common_timeline[start_index - 1] - common_start_date)):
    start_index -= 1

# Find the index of the closest value less than or equal to the end date
end_index = np.searchsorted(common_timeline, common_end_date, side='left')
if end_index < len(common_timeline) and (abs(common_timeline[start_index] - common_end_date)) > (abs(common_timeline[start_index - 1] - common_end_date)):
    end_index -= 1

# Filter the timeline
filtered_timeline = common_timeline[start_index:end_index]

print("Filtered Timeline:", filtered_timeline)
# Out:
# Filtered Timeline: [ 35  42  49  56  63  70  77  84  91  98 105 112 119 126 133 140 147 154
#  161 168 175 182 189 196 203 210 217 224 231 238 245 252 259 266 273 280
#  287 294 301 308 315 322]

# %%
# Function to interpolate data for a subject and count artificial data points
def interpolate_subject_data(subject_df, common_timeline):
    subject_timeline = (subject_df['Gestational age (GA)/days']).values.reshape(-1, 1)
    interpolated_data = {}
    original_data_points = np.array(sorted(subject_timeline)).flatten()
    artificial_data_points = 0

    float_columns = subject_df.select_dtypes(include=[np.float64, np.float32]).columns
    string_columns = subject_df.select_dtypes(include=[object]).columns

    interpolated_timeline = []
    for feature in float_columns:
        interpolated_values = []
        for day in common_timeline:

            if day not in original_data_points:

                # Find the nearest lower and higher data points
                lower_points = original_data_points[original_data_points < day]
                higher_points = original_data_points[original_data_points > day]

                if lower_points.size == 0 or higher_points.size == 0:
                    continue  # Skip if there are no points to interpolate from

                lower_point = lower_points.max()
                higher_point = higher_points.min()

                # Calculate the weights
                weight_lower = round(higher_point - day)
                weight_higher = round(day - lower_point)

                if weight_lower > 10 or weight_higher > 10:
                    continue  # Skip if the weights are too large

                total_weight = weight_lower + weight_higher

                # Get the values at the lower and higher points
                value_lower = subject_df.loc[subject_df['Gestational age (GA)/days'] == lower_point, feature].values[0]
                value_higher = subject_df.loc[subject_df['Gestational age (GA)/days'] == higher_point, feature].values[0]

                # Calculate the weighted average
                interpolated_value = (value_lower * weight_lower + value_higher * weight_higher) / total_weight
                interpolated_values.append(interpolated_value)
                interpolated_timeline.append(day)
            else:
                # Find the most recent data point before the current day
                previous_points = original_data_points[original_data_points < day]
                previous_point = previous_points.max() if previous_points.size > 0 else np.nan

                # Find the closest data point after the current day
                next_points = original_data_points[original_data_points > day]
                next_point = next_points.min() if next_points.size > 0 else np.nan

                # Check if the difference with the previous data point is within 7 days
                if not pd.isna(previous_point) and (day - previous_point) <= 7:
                    feature_value = subject_df.loc[subject_df['Gestational age (GA)/days'] == day, feature].values
                    if feature_value.size > 0:
                        interpolated_values.append(feature_value[0])

                # Check if the difference with the next data point is within 7 days
                if not pd.isna(next_point) and (next_point - day) <= 7:
                    feature_value = subject_df.loc[subject_df['Gestational age (GA)/days'] == day, feature].values
                    if feature_value.size > 0:
                        interpolated_values.append(feature_value[0])

        for col in string_columns:
          interpolated_data[col] = subject_df[col].iloc[0]

        interpolated_data[feature] = interpolated_values

    # Calculate the number of artificial data points
    for day in common_timeline:
        if day not in original_data_points:
            artificial_data_points += 1

    interpolated_df = pd.DataFrame(interpolated_data)

    total_points = len(common_timeline)
    percent_artificial = (artificial_data_points / total_points) * 100

    return interpolated_df, artificial_data_points, total_points, percent_artificial

# Apply interpolation and calculate artificial data for each subject
interpolated_subjects = []
artificial_data_summary = []

for subject_id in df_info['Subject ID'].unique():
    subject_df = df[df['Subject ID'] == subject_id]
    interpolated_df, artificial_data_points, total_points, percent_artificial = interpolate_subject_data(subject_df, common_timeline)
    interpolated_subjects.append(interpolated_df)
    artificial_data_summary.append({
        'Subject ID': subject_id,
        'Artificial Data Points': artificial_data_points,
        'Total Points': total_points,
        'Percent Artificial Data': percent_artificial
    })

# Concatenate all interpolated data
interpolated_df = pd.concat(interpolated_subjects, ignore_index=True)
artificial_data_summary_df = pd.DataFrame(artificial_data_summary)

# %%
artificial_data_summary_df
# Out:
#    Subject ID  Artificial Data Points  Total Points  Percent Artificial Data
# 0        DP01                      48            48               100.000000
# 1        DP02                      41            48                85.416667
# 2        DP03                      42            48                87.500000
# 3        DP04                      36            48                75.000000
# 4        DP05                      35            48                72.916667
# 5        DP06                      44            48                91.666667
# 6        DP07                      48            48               100.000000
# 7        DP08                      46            48                95.833333
# 8        DP09                      48            48               100.000000
# 9        DP10                      48            48               100.000000
# 10       DP11                      45            48                93.750000
# 11       DP12                      40            48                83.333333
# 12       DP13                      46            48                95.833333
# 13       DP14                      48            48               100.000000
# 14       DP15                      48            48               100.000000
# 15       DP16                      43            48                89.583333
# 16       DP17                      43            48                89.583333
# 17       DP18                      45            48                93.750000
# 18       DP19                      46            48                95.833333
# 19       DP20                      41            48                85.416667
# 20       DP21                      42            48                87.500000
# 21       DP22                      42            48                87.500000
# 22       DP23                      46            48                95.833333
# 23       DP24                      35            48                72.916667
# 24       DP25                      38            48                79.166667
# 25       DP26                      39            48                81.250000
# 26       DP27                      48            48               100.000000
# 27       DP28                      48            48               100.000000
# 28       DP29                      44            48                91.666667
# 29       DP30                      42            48                87.500000

# %%
interpolated_df = interpolated_df.drop_duplicates()

# %%
interpolated_df = interpolated_df.reset_index(drop=True)
interpolated_df
# Out:
#     Subject ID                   Cohort Labor onset  \
# 0         DP01                Discovery     natural
# 1         DP01                Discovery     natural
# 2         DP01                Discovery     natural
# 3         DP01                Discovery     natural
# 4         DP01                Discovery     natural
# ..         ...                      ...         ...
# 696       DP30  Validation (Test Set 1)     natural
# 697       DP30  Validation (Test Set 1)     natural
# 698       DP30  Validation (Test Set 1)     natural
# 699       DP30  Validation (Test Set 1)     natural
# 700       DP30  Validation (Test Set 1)     natural
#
#      Gestational age (GA)/days  Gestational age (GA)/weeks  Birth GA/weeks  \
# 0                         35.0                         5.0       38.714286
# 1                         42.0                         6.0       38.714286
# 2                         49.0                         7.0       38.714286
# 3                         56.0                         8.0       38.714286
# 4                         63.0                         9.0       38.714286
# ..                         ...                         ...             ...
# 696                      245.0                        35.0       38.857143
# 697                      252.0                        36.0       38.857143
# 698                      259.0                        37.0       38.857143
# 699                      266.0                        38.0       38.857143
# 700                      273.0                        39.0       38.857143
#
#      (+)-.alpha.-Tocopherol  (R)-2-Hydroxycaprylic acid  1,4-Dihydroxybenzene  \
# 0                 12.187246                   10.075398              9.315506
# 1                 12.643866                    9.871381              7.523938
# 2                 13.632884                   10.025761              4.431244
# 3                 12.125875                   10.253546              5.250766
# 4                 12.657642                   10.162621              8.130034
# ..                      ...                         ...                   ...
# 696               12.115260                   11.037353              6.541048
# 697               12.469027                   11.543126              6.903586
# 698               14.027342                   10.293517              7.147000
# 699               12.575002                   10.068778              9.200918
# 700               13.453395                   10.114277              8.743941
#
#      1-Methylxanthine  ...  cis-5,8,11,14,17-Eicosapentaenoic acid  \
# 0           10.907293  ...                               11.183291
# 1           10.954945  ...                               11.018465
# 2            9.715949  ...                               10.537209
# 3            9.805404  ...                               10.672192
# 4           10.349446  ...                               10.788551
# ..                ...  ...                                     ...
# 696         10.235494  ...                               11.053052
# 697         10.341836  ...                               11.048241
# 698         10.042527  ...                               10.755617
# 699          9.555815  ...                               10.292866
# 700          8.244443  ...                                9.950208
#
#      cis-5-Dodecenoic acid  cis-9-Palmitoleic acid  d-LIMONENE  gamma-CEHC  \
# 0                10.799411               12.059483    5.643133   10.495975
# 1                10.230143               11.844556    5.497642    9.847823
# 2                 9.326564               11.616709    6.736850    9.342694
# 3                 8.790673               11.874221    7.195789   10.022338
# 4                 8.972928               11.831649    6.579638   10.032035
# ..                     ...                     ...         ...         ...
# 696               9.530414               12.100110    6.634040    9.352964
# 697               9.437662               12.121246    6.724391    9.135123
# 698               9.205752               12.077126    6.181048    9.846376
# 699               9.692128               12.429983    6.789644    8.926737
# 700               9.645435               12.059390    7.880887    9.496995
#
#      gamma-Glutamylleucine  ketoisocaproic acid   p-Cresol  \
# 0                12.157863            14.377687  10.635153
# 1                12.110144            14.217800  10.610887
# 2                12.174268            14.225116  10.848017
# 3                12.604769            14.749239  10.571532
# 4                12.329358            14.939134  10.303965
# ..                     ...                  ...        ...
# 696              12.271830            14.366054  10.805234
# 697              11.884873            14.472117  10.867624
# 698              12.123202            14.680196  10.440013
# 699              12.228364            14.663350  10.208924
# 700              12.610548            14.818217  10.620437
#
#      phenylacetylglutamine  trans-Vaccenic acid
# 0                14.263246            11.150043
# 1                14.001904            10.924683
# 2                14.178476            10.705275
# 3                14.042197            11.155579
# 4                13.876263            11.085732
# ..                     ...                  ...
# 696              14.887704            11.551004
# 697              14.675015            10.905095
# 698              14.345236            10.808394
# 699              13.998535            11.138388
# 700              14.579306            11.317374
#
# [701 rows x 270 columns]

# %%
interpolated_df[interpolated_df['Subject ID'] == 'DP21']
# Out:
#     Subject ID     Cohort Labor onset  Gestational age (GA)/days  \
# 458       DP21  Discovery     natural                      126.0
# 459       DP21  Discovery     natural                      133.0
# 460       DP21  Discovery     natural                      140.0
# 461       DP21  Discovery     natural                      147.0
# 462       DP21  Discovery     natural                      154.0
# 463       DP21  Discovery     natural                      161.0
# 464       DP21  Discovery     natural                      168.0
# 465       DP21  Discovery     natural                      210.0
# 466       DP21  Discovery     natural                      217.0
# 467       DP21  Discovery     natural                      224.0
# 468       DP21  Discovery     natural                      231.0
# 469       DP21  Discovery     natural                      259.0
#
#      Gestational age (GA)/weeks  Birth GA/weeks  (+)-.alpha.-Tocopherol  \
# 458                        18.0       38.571429               12.425802
# 459                        19.0       38.571429               13.488137
# 460                        20.0       38.571429               13.246029
# 461                        21.0       38.571429               12.467784
# 462                        22.0       38.571429               12.489635
# 463                        23.0       38.571429               13.988499
# 464                        24.0       38.571429               13.537356
# 465                        30.0       38.571429               10.178591
# 466                        31.0       38.571429                9.922932
# 467                        32.0       38.571429               10.948244
# 468                        33.0       38.571429               12.648284
# 469                        37.0       38.571429               12.825349
#
#      (R)-2-Hydroxycaprylic acid  1,4-Dihydroxybenzene  1-Methylxanthine  ...  \
# 458                    9.940151              9.346458         10.948009  ...
# 459                    9.854098              9.444458         10.368734  ...
# 460                   10.221606              9.384963         10.536216  ...
# 461                   10.382514              4.543732         11.208936  ...
# 462                   10.195934              8.954138         11.247966  ...
# 463                   10.082340             10.240554         11.428982  ...
# 464                   10.167389              9.441791         10.891179  ...
# 465                   10.001586              9.319354         10.960209  ...
# 466                    9.987443              8.029249         10.777103  ...
# 467                   10.120422              7.635790         11.122960  ...
# 468                   10.082579              5.591463         11.069865  ...
# 469                   10.481117              4.569970         10.515028  ...
#
#      cis-5,8,11,14,17-Eicosapentaenoic acid  cis-5-Dodecenoic acid  \
# 458                               10.890095              10.409081
# 459                               10.721470               9.898654
# 460                               10.536693              10.425716
# 461                               11.003658              10.111463
# 462                                9.971164               9.401481
# 463                               10.625949               8.844947
# 464                               10.524493               9.304888
# 465                               10.343619               8.650760
# 466                               10.640779               8.961600
# 467                               10.601510               8.683241
# 468                               10.585704               8.567937
# 469                               10.732089               9.866045
#
#      cis-9-Palmitoleic acid  d-LIMONENE  gamma-CEHC  gamma-Glutamylleucine  \
# 458               12.320187    7.020098   10.516925              12.065996
# 459               12.230804    5.331199   10.157811              11.956406
# 460               12.393004    6.748009   10.106812              12.287791
# 461               12.228382    6.140041    9.717163              12.087499
# 462               12.024649    6.353860    9.969766              12.896635
# 463               12.172595    5.710784    9.687481              12.042356
# 464               12.037641    6.210856    9.870218              12.034437
# 465               11.940205    5.775387    9.787532              12.285890
# 466               12.069779    6.535149    9.749425              12.231994
# 467               12.093678    6.621639   10.007895              12.185041
# 468               11.953050    5.939196    9.956270              12.098249
# 469               12.078110    6.267692   10.439969              12.065287
#
#      ketoisocaproic acid   p-Cresol  phenylacetylglutamine  \
# 458            15.078192  11.697351              15.374608
# 459            14.367358  11.957828              15.641462
# 460            14.306134  11.710425              15.507585
# 461            13.597653  11.825458              15.374558
# 462            15.037879  11.981087              15.762672
# 463            14.091961  11.851552              15.602911
# 464            14.208508  12.034598              15.729341
# 465            15.144465  11.824410              15.621938
# 466            14.216073  11.867467              15.653524
# 467            13.787838  12.072946              15.801390
# 468            14.083548  11.969848              15.801352
# 469            14.074192  11.915319              15.856985
#
#      trans-Vaccenic acid
# 458            11.736492
# 459            11.514334
# 460            11.687867
# 461            11.739387
# 462            10.928602
# 463            11.437537
# 464            11.306020
# 465            10.984773
# 466            11.106400
# 467            11.137249
# 468            11.021689
# 469            11.143671
#
# [12 rows x 270 columns]

# %%
df.to_csv('pregnancy_preprocessed.csv', index=False)
interpolated_df.to_csv('pregnancy_interpolated_preprocessed.csv', index=False)
